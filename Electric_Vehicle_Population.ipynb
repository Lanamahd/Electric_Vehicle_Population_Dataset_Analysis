# %% [markdown]
# # Displaying the Dataset

# %%
import pandas as pd
df = pd.read_csv("C:/Users/asus/OneDrive/Desktop/assignment_one_ML/Electric_Vehicle_Population_Data.csv") 
df
# Out:
#         VIN (1-10)     County              City State  Postal Code  \
# 0       5UXTA6C0XM     Kitsap           Seabeck    WA      98380.0
# 1       5YJ3E1EB1J     Kitsap           Poulsbo    WA      98370.0
# 2       WP0AD2A73G  Snohomish           Bothell    WA      98012.0
# 3       5YJ3E1EB5J     Kitsap         Bremerton    WA      98310.0
# 4       1N4AZ1CP3K       King           Redmond    WA      98052.0
# ...            ...        ...               ...   ...          ...
# 210160  KNDCM3LD8J      Grant        Moses Lake    WA      98837.0
# 210161  JM3KKBHA0R     Kitsap         Bremerton    WA      98312.0
# 210162  JTMAB3FV3P     Pierce  University Place    WA      98466.0
# 210163  5YJ3E1EA1M       King          Kirkland    WA      98034.0
# 210164  7SAYGDEE0P    Spokane           Spokane    WA      99208.0
#
#         Model Year     Make       Model  \
# 0             2021      BMW          X5
# 1             2018    TESLA     MODEL 3
# ...

# %% [markdown]
# # 1. Data Cleaning and Feature Engineering

# %% [markdown]
# # 1.1. Document Missing Values & Missing Value Strategies

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         5
# Base MSRP                                              5
# Legislative District                                 445
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       4
# ...

# %% [markdown]
# The features that have missing values are: Country, City, Postal Code, Electric Range, Base MSRP, Legislative District,
# Vehicle Location, Electric Utility, and 2020 Census Tract.

# %% [markdown]
# # Cleaning Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210165 entries, 0 to 210164
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         210165 non-null  object
#  1   County                                             210161 non-null  object
#  2   City                                               210161 non-null  object
#  3   State                                              210165 non-null  object
#  4   Postal Code                                        210161 non-null  float64
#  5   Model Year                                         210165 non-null  int64
#  6   Make                                               210165 non-null  object
#  7   Model                                              210165 non-null  object
# ...

# %% [markdown]
# # a. Converting Postal Code from object to float

# %%
df['Postal Code'] = df['Postal Code'].astype(str)
df['Postal Code'] = df['Postal Code'].astype(float)
df['Postal Code'].info()
df
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 210165 entries, 0 to 210164
# Series name: Postal Code
# Non-Null Count   Dtype
# --------------   -----
# 210161 non-null  float64
# dtypes: float64(1)
# memory usage: 1.6 MB
#         VIN (1-10)     County              City State  Postal Code  \
# 0       5UXTA6C0XM     Kitsap           Seabeck    WA      98380.0
# 1       5YJ3E1EB1J     Kitsap           Poulsbo    WA      98370.0
# 2       WP0AD2A73G  Snohomish           Bothell    WA      98012.0
# 3       5YJ3E1EB5J     Kitsap         Bremerton    WA      98310.0
# 4       1N4AZ1CP3K       King           Redmond    WA      98052.0
# ...            ...        ...               ...   ...          ...
# 210160  KNDCM3LD8J      Grant        Moses Lake    WA      98837.0
# 210161  JM3KKBHA0R     Kitsap         Bremerton    WA      98312.0
# 210162  JTMAB3FV3P     Pierce  University Place    WA      98466.0
# 210163  5YJ3E1EA1M       King          Kirkland    WA      98034.0
# ...

# %% [markdown]
# # b. Converting Legislative District from float to integer

# %%
df['Legislative District'] = df['Legislative District'].astype(float) 
df['Legislative District'] = df['Legislative District'].fillna(0).astype(int)
df['Legislative District'].info()
df
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 210165 entries, 0 to 210164
# Series name: Legislative District
# Non-Null Count   Dtype
# --------------   -----
# 210165 non-null  int64
# dtypes: int64(1)
# memory usage: 1.6 MB
#         VIN (1-10)     County              City State  Postal Code  \
# 0       5UXTA6C0XM     Kitsap           Seabeck    WA      98380.0
# 1       5YJ3E1EB1J     Kitsap           Poulsbo    WA      98370.0
# 2       WP0AD2A73G  Snohomish           Bothell    WA      98012.0
# 3       5YJ3E1EB5J     Kitsap         Bremerton    WA      98310.0
# 4       1N4AZ1CP3K       King           Redmond    WA      98052.0
# ...            ...        ...               ...   ...          ...
# 210160  KNDCM3LD8J      Grant        Moses Lake    WA      98837.0
# 210161  JM3KKBHA0R     Kitsap         Bremerton    WA      98312.0
# 210162  JTMAB3FV3P     Pierce  University Place    WA      98466.0
# 210163  5YJ3E1EA1M       King          Kirkland    WA      98034.0
# ...

# %% [markdown]
# # 1.1.1. Filling the missing values in Country

# %%
most_frequent_county = df['County'].mode()[0]
print("Most frequent county:", most_frequent_county)
# Out:
# Most frequent county: King

# %% [markdown]
# Since the County feature is object type, we will fill the missing values using mode. In the above cell you can see
# the most frequent value in this feature which is 'King'.

# %%
df[df['County'] == 'King']
# Out:
#         VIN (1-10) County      City State  Postal Code  Model Year     Make  \
# 4       1N4AZ1CP3K   King   Redmond    WA      98052.0        2019   NISSAN
# 6       5YJYGDEEXL   King    Renton    WA      98055.0        2020    TESLA
# 7       5UXTS1C06M   King   Seattle    WA      98107.0        2021      BMW
# 8       1N4AZ0CP0F   King  Bellevue    WA      98007.0        2015   NISSAN
# 9       5YJSA1E20H   King   Seattle    WA      98125.0        2017    TESLA
# ...            ...    ...       ...   ...          ...         ...      ...
# 210146  WB523CF0XP   King    Renton    WA      98059.0        2023      BMW
# 210154  KM8K23AGXL   King   Seattle    WA      98103.0        2020  HYUNDAI
# 210155  1C4RJXP67R   King    Renton    WA      98059.0        2024     JEEP
# 210156  7SAYGDEF1N   King   Seattle    WA      98121.0        2022    TESLA
# 210163  5YJ3E1EA1M   King  Kirkland    WA      98034.0        2021    TESLA
#
# ...

# %% [markdown]
# Note that the data with counties equal to King are 107115 before filling the null values in this feature.

# %%
df['County'] = df['County'].fillna(most_frequent_county) # Fill null values in 'County' column with the most frequent value

print("Null values in 'County' column after fill:", df['County'].isnull().sum()) #Check to confirm null values are filled
# Out:
# Null values in 'County' column after fill: 0

# %%
df[df['County'] == 'King']
# Out:
#         VIN (1-10) County      City State  Postal Code  Model Year     Make  \
# 4       1N4AZ1CP3K   King   Redmond    WA      98052.0        2019   NISSAN
# 6       5YJYGDEEXL   King    Renton    WA      98055.0        2020    TESLA
# 7       5UXTS1C06M   King   Seattle    WA      98107.0        2021      BMW
# 8       1N4AZ0CP0F   King  Bellevue    WA      98007.0        2015   NISSAN
# 9       5YJSA1E20H   King   Seattle    WA      98125.0        2017    TESLA
# ...            ...    ...       ...   ...          ...         ...      ...
# 210146  WB523CF0XP   King    Renton    WA      98059.0        2023      BMW
# 210154  KM8K23AGXL   King   Seattle    WA      98103.0        2020  HYUNDAI
# 210155  1C4RJXP67R   King    Renton    WA      98059.0        2024     JEEP
# 210156  7SAYGDEF1N   King   Seattle    WA      98121.0        2022    TESLA
# 210163  5YJ3E1EA1M   King  Kirkland    WA      98034.0        2021    TESLA
#
# ...

# %% [markdown]
# After filling the null values with "King," we observed that the number of rows where the county is "King" increased
# to 107119. Initially, there were 4 null values in the County column. Before filling, "King" was the most frequent value with 107,115 occurrences. After filling, the count of "King" rows increased to 107119.

# %% [markdown]
# # 1.1.2. Filling the missing values in City

# %%
most_frequent_county = df['City'].mode()[0]
print("Most frequent county:", most_frequent_county)
# Out:
# Most frequent county: Seattle

# %% [markdown]
# Since the City feature is object type, we will fill the missing values using mode. In the above cell you can see
# the most frequent value in this feature which is 'Seattle'.

# %%
df[df['City'] == 'Seattle']
# Out:
#         VIN (1-10) County     City State  Postal Code  Model Year        Make  \
# 7       5UXTS1C06M   King  Seattle    WA      98107.0        2021         BMW
# 9       5YJSA1E20H   King  Seattle    WA      98125.0        2017       TESLA
# 19      5YJ3E1EB7K   King  Seattle    WA      98115.0        2019       TESLA
# 34      5YJ3E1EB6J   King  Seattle    WA      98102.0        2018       TESLA
# 44      WBA5P7C0XM   King  Seattle    WA      98106.0        2021         BMW
# ...            ...    ...      ...   ...          ...         ...         ...
# 210076  3C3CFFGE5E   King  Seattle    WA      98178.0        2014        FIAT
# 210089  YV4H60DZ7N   King  Seattle    WA      98107.0        2022       VOLVO
# 210121  WVGDMPE20M   King  Seattle    WA      98144.0        2021  VOLKSWAGEN
# 210154  KM8K23AGXL   King  Seattle    WA      98103.0        2020     HYUNDAI
# 210156  7SAYGDEF1N   King  Seattle    WA      98121.0        2022       TESLA
#
# ...

# %% [markdown]
# Note that the data with cities equal to Seattle are 33854 before filling the null values in this feature.

# %%
df['City'] = df['City'].fillna(most_frequent_county) # Fill null values in 'County' column with the most frequent value

print("Null values in 'City' column after fill:", df['City'].isnull().sum()) # Check to confirm null values are filled
# Out:
# Null values in 'City' column after fill: 0

# %%
df[df['City'] == 'Seattle']
# Out:
#         VIN (1-10) County     City State  Postal Code  Model Year        Make  \
# 7       5UXTS1C06M   King  Seattle    WA      98107.0        2021         BMW
# 9       5YJSA1E20H   King  Seattle    WA      98125.0        2017       TESLA
# 19      5YJ3E1EB7K   King  Seattle    WA      98115.0        2019       TESLA
# 34      5YJ3E1EB6J   King  Seattle    WA      98102.0        2018       TESLA
# 44      WBA5P7C0XM   King  Seattle    WA      98106.0        2021         BMW
# ...            ...    ...      ...   ...          ...         ...         ...
# 210076  3C3CFFGE5E   King  Seattle    WA      98178.0        2014        FIAT
# 210089  YV4H60DZ7N   King  Seattle    WA      98107.0        2022       VOLVO
# 210121  WVGDMPE20M   King  Seattle    WA      98144.0        2021  VOLKSWAGEN
# 210154  KM8K23AGXL   King  Seattle    WA      98103.0        2020     HYUNDAI
# 210156  7SAYGDEF1N   King  Seattle    WA      98121.0        2022       TESLA
#
# ...

# %% [markdown]
# After filling the null values with "Seattle," we observed that the number of rows where the city is "Seattle" increased
# to 33858. Initially, there were 4 null values in the City column. Before filling, "Seattle" was the most frequent value with 33854 occurrences. After filling, the count of "Seattle" rows increased to 33858.

# %% [markdown]
# # 1.1.3. Filling the missing values in Postal Code

# %% [markdown]
# To handle missing values in the Postal Code column, we filled them with the median postal code for each respective county.

# %%
df['Postal Code'] = df.groupby('County')['Postal Code'].transform(lambda x: x.fillna(x.median()))

df['Postal Code'].isna().sum()

df[df['Postal Code'].isnull()]
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %% [markdown]
# After filling the missing Postal Code values with the median postal code for each county, we checked to see if any
# null values remained. The line df['Postal Code'].isna().sum() shows how many missing values are left, if any. Displaying df[df['Postal Code'].isnull()] helps us find any rows where Postal Code is still empty, making sure our data is complete.

# %% [markdown]
# # 1.1.4. Filling the missing values in Electric Range

# %% [markdown]
# To handle missing values in the Electric Range column, we filled them with the median Electric Range for each respective county.

# %%
df['Electric Range'] = df.groupby('County')['Electric Range'].transform(lambda x: x.fillna(x.median()))

df['Electric Range'].isna().sum()

df[df['Electric Range'].isnull()]
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %% [markdown]
# After filling the missing Electric Range values with the median range for each county, we checked to see if any null
# values remained. The line df['Electric Range'].isna().sum() shows how many missing values are left, if any. Displaying df[df['Electric Range'].isnull()] helps us find any rows where Electric Range is still empty, ensuring our data is complete.

# %% [markdown]
# # 1.1.5. Filling the missing values in Base MSRP

# %% [markdown]
# To handle missing values in the Base MSRP column, we filled them with the median Base MSRP for each respective county.

# %%
df['Base MSRP'] = df.groupby('County')['Base MSRP'].transform(lambda x: x.fillna(x.median()))

df['Base MSRP'].isna().sum()

df[df['Base MSRP'].isnull()]
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %% [markdown]
# After filling the missing Base MSRP values with the median range for each county, we checked to see if any null
# values remained. The line df['Base MSRP'].isna().sum() shows how many missing values are left, if any. Displaying df[df['Base MSRP'].isnull()] helps us find any rows where Base MSRP is still empty, ensuring our data is complete.

# %% [markdown]
# # 1.1.6. Filling the missing values in Vehicle Location

# %%
most_frequent_county = df['Vehicle Location'].mode()[0]
print("Most frequent county:", most_frequent_county)
# Out:
# Most frequent county: POINT (-122.13158 47.67858)

# %% [markdown]
# Since the Vehicle Location feature is object type, we will fill the missing values using mode. In the above cell you can see
# the most frequent value in this feature which is 'POINT (-122.13158 47.67858)'.

# %%
df['Vehicle Location'] = df['Vehicle Location'].fillna(most_frequent_county) # Fill null values in 'County' column with the most frequent value

print("Null values in 'Vehicle Location' column after fill:", df['Vehicle Location'].isnull().sum())  # Check to confirm null values are filled
# Out:
# Null values in 'Vehicle Location' column after fill: 0

# %% [markdown]
# # 1.1.7. Filling the missing values in Electric Utility

# %%
most_frequent_county = df['Electric Utility'].mode()[0]
print("Most frequent county:", most_frequent_county)
# Out:
# Most frequent county: PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)

# %%
df['Electric Utility'] = df['Electric Utility'].fillna(most_frequent_county) # Fill null values in 'County' column with the most frequent value

print("Null values in 'Electric Utility' column after fill:", df['Electric Utility'].isnull().sum()) # Check to confirm null values are filled
# Out:
# Null values in 'Electric Utility' column after fill: 0

# %% [markdown]
# Since the Electric Utility feature is object type, we will fill the missing values using mode. In the above cell you
# can see the most frequent value in this feature which is 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'.

# %% [markdown]
# # 1.1.8. Filling the missing values in 2020 Census Tract

# %% [markdown]
# To handle missing values in the 2020 Census Tract column, we filled them with the median 2020 Census Tract for each respective
# county.

# %%
df['2020 Census Tract'] = df.groupby('County')['2020 Census Tract'].transform(lambda x: x.fillna(x.median()))

df['2020 Census Tract'].isna().sum()

df[df['2020 Census Tract'].isnull()]
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %% [markdown]
# After filling the missing 2020 Census Tract values with the median range for each county, we checked to see if any null
# values remained. The line df['2020 Census Tract'].isna().sum() shows how many missing values are left, if any. Displaying df[df['2020 Census Tract'].isnull()] helps us find any rows where 2020 Census Tract is still empty, ensuring our data is complete.

# %% [markdown]
# # The results after filling all the missing values:

# %%
df.isna().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %% [markdown]
# # 1.2. Feature Encoding: Encode categorical features (e.g., Make, Model) using techniques like one-hot encoding.

# %% [markdown]
# In this section, we applied one-hot encoding to the categorical features (VIN (1-10), County, City, etc.) to convert them into
# numerical format. Using pd.get_dummies, each category in these columns is transformed into separate binary columns, making the data suitable for machine learning models. The resulting df_encoded DataFrame shows the encoded data with the first few rows displayed using head().

# %%
# List of categorical features 
categorical_columns = ['VIN (1-10)', 'County', 'City', 'State', 'Make', 'Model', 
                       'Electric Vehicle Type', 'Clean Alternative Fuel Vehicle (CAFV) Eligibility',
                       'Vehicle Location', 'Electric Utility']

df_encoded = pd.get_dummies(df, columns=categorical_columns, prefix=categorical_columns) # Apply one-hot encoding to the specified columns

df_encoded.head() # Display the first few rows of the resulting DataFrame
# Out:
#    Postal Code  Model Year  Electric Range  Base MSRP  Legislative District  \
# 0      98380.0        2021            30.0        0.0                    35
# 1      98370.0        2018           215.0        0.0                    23
# 2      98012.0        2016            15.0        0.0                     1
# 3      98310.0        2018           215.0        0.0                    23
# 4      98052.0        2019           150.0        0.0                    45
#
#    DOL Vehicle ID  2020 Census Tract  VIN (1-10)_1C4JJXN60P  \
# 0       267929112       5.303509e+10                  False
# 1       475911439       5.303509e+10                  False
# 2       101971278       5.306105e+10                  False
# 3       474363746       5.303508e+10                  False
# 4       476346482       5.303303e+10                  False
#
#    VIN (1-10)_1C4JJXN61P  VIN (1-10)_1C4JJXN62P  ...  \
# 0                  False                  False  ...
# ...

# %% [markdown]
# After applying one-hot encoding to the categorical features, each unique category within these columns has been transformed
# into a separate binary column. In the encoded DataFrame, a value of 1 indicates the presence of that specific category for a row, while 0 indicates its absence. For example, in the Electric Utility columns, Electric Utility_PUGET SOUND ENERGY INC being True shows that this utility serves the corresponding vehicle.

# %% [markdown]
# # 1.3.  Normalization: Normalize numerical features if necessary for chosen analysis methods.

# %% [markdown]
# In this section, we used Min-Max Scaling to normalize the numerical features (Model Year, Electric Range, Base MSRP, etc.),
# transforming their values to a range between 0 and 1. This step helps ensure that all numerical features are on a similar scale, which can improve model performance and convergence for certain algorithms. The normalized values are stored back in df_encoded, and we display the first few rows to verify the changes.

# %%
from sklearn.preprocessing import MinMaxScaler

# List of numerical columns to normalize
numerical_columns = ['Model Year', 'Electric Range', 'Base MSRP', 'Legislative District', 
                     'DOL Vehicle ID', '2020 Census Tract']

scaler = MinMaxScaler() # Initialize the MinMaxScaler

# Apply the scaler to the numerical columns and store the result in a new DataFrame
df_encoded[numerical_columns] = scaler.fit_transform(df_encoded[numerical_columns])

df_encoded.head() # Display the first few rows of the normalized DataFrame
# Out:
#    Postal Code  Model Year  Electric Range  Base MSRP  Legislative District  \
# 0      98380.0    0.846154        0.089021        0.0              0.714286
# 1      98370.0    0.730769        0.637982        0.0              0.469388
# 2      98012.0    0.653846        0.044510        0.0              0.020408
# 3      98310.0    0.730769        0.637982        0.0              0.469388
# 4      98052.0    0.769231        0.445104        0.0              0.918367
#
#    DOL Vehicle ID  2020 Census Tract  VIN (1-10)_1C4JJXN60P  \
# 0        0.559050           0.945730                  False
# 1        0.993024           0.945730                  False
# 2        0.212763           0.946202                  False
# 3        0.989794           0.945730                  False
# 4        0.993932           0.945693                  False
#
#    VIN (1-10)_1C4JJXN61P  VIN (1-10)_1C4JJXN62P  ...  \
# 0                  False                  False  ...
# ...

# %% [markdown]
# Note that after the normalization the numerical features became between 0 to 1.

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# # 2.1. Descriptive Statistics: Calculate summary statistics (mean, median, standard deviation) for numerical features.

# %%
numerical_columns = ['Model Year', 'Electric Range', 'Base MSRP', 'Legislative District', 
                     'DOL Vehicle ID', '2020 Census Tract']

# Calculate mean, median, and standard deviation for each numerical feature
descriptive_stats = pd.DataFrame({
    'Mean': df[numerical_columns].mean(),
    'Median': df[numerical_columns].median(),
    'Standard Deviation': df[numerical_columns].std()
})

descriptive_stats
# Out:
#                               Mean        Median  Standard Deviation
# Model Year            2.021049e+03  2.022000e+03        2.988941e+00
# Electric Range        5.060107e+01  0.000000e+00        8.697251e+01
# Base MSRP             8.976769e+02  0.000000e+00        7.653589e+03
# Legislative District  2.886870e+01  3.200000e+01        1.495185e+01
# DOL Vehicle ID        2.290774e+08  2.405164e+08        7.115519e+07
# 2020 Census Tract     5.297929e+10  5.303303e+10        1.551466e+09

# %% [markdown]
# - Model Year: The mean model year is around 2021, with a standard deviation of approximately 2.99, indicating that most vehicles
#   are from recent years, but there is some variation.
# - Electric Range: The mean electric range is about 50 miles, with a high standard deviation (86.97), suggesting a wide variation in range. The median of 0 indicates that many entries may have missing or zero values for this feature.
# - Base MSRP: The mean base MSRP is approximately $897.67, with a standard deviation of 765.36, indicating a substantial range in vehicle prices.
# - Legislative District: The mean and standard deviation for legislative districts suggest a fairly even spread across districts.
# - DOL Vehicle ID and 2020 Census Tract: These identifiers have large values due to the nature of IDs, and they have high standard deviations, which is expected as they are unique identifiers rather than typical numeric variables.

# %% [markdown]
# # 2.2. Spatial Distribution: Visualize the spatial distribution of EVs across locations (e.g., maps).

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Extract latitude and longitude from the 'Vehicle Location' column
df['longitude'] = df['Vehicle Location'].apply(lambda x: float(x.split()[1][1:]))
df['latitude'] = df['Vehicle Location'].apply(lambda x: float(x.split()[2][:-1]))

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['longitude'], df['latitude']))  # Convert to a GeoDataFrame

gdf.set_crs(epsg=4326, inplace=True)  # Set the coordinate reference system (CRS) to WGS84 (EPSG:4326)

fig, ax = plt.subplots(figsize=(10, 10))  # Plot the spatial distribution of EVs with a basemap

# Convert to Web Mercator for compatibility with contextily basemaps
gdf = gdf.to_crs(epsg=3857)
gdf.plot(ax=ax, markersize=5, color='blue', alpha=0.6, marker='o', label='EV Location')

# Add the basemap
import contextily as ctx
ctx.add_basemap(ax, crs=gdf.crs, source=ctx.providers.OpenStreetMap.Mapnik)

ax.set_title("Spatial Distribution of Electric Vehicles in Washington State")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend()
plt.show()

# %% [markdown]
# The map reveals a dense concentration of electric vehicles (EVs) primarily in the western region of Washington State,
# particularly
# around the Puget Sound area. This region includes major cities like Seattle, Tacoma, and Bellevue, which are known for having well-established infrastructure and policies supporting EV adoption. The high density of points here suggests that urban and suburban areas in western Washington, especially near Seattle, lead in EV registrations. In contrast, more rural or eastern parts of Washington show fewer data points, indicating a lower EV adoption rate in those areas. This pattern may be due to the availability of charging infrastructure, population density, and local incentives supporting EV use in more urbanized areas of the state.

# %% [markdown]
# # 2.3. Model Popularity: Analyze the popularity of different EV models (categorical data) and identify any trends.

# %% [markdown]
# # 2.3.1. Analyze Model Popularity

# %% [markdown]
# To see the most popular models we used value_counts()

# %%
model_counts = df['Model'].value_counts()  # Count the occurrences of each model

# Display the top 10 most popular models
top_10_models = model_counts.head(10)
print("Top 10 EV Models by Popularity:")
print(top_10_models)

# Plot the popularity of the top 10 EV models
plt.figure(figsize=(12, 6))
top_10_models.plot(kind='bar', color='skyblue')
plt.title("Top 10 Most Popular EV Models")
plt.xlabel("EV Model")
plt.ylabel("Number of Registrations")
plt.xticks(rotation=45)
plt.show()
# Out:
# Top 10 EV Models by Popularity:
# Model
# MODEL Y           44038
# MODEL 3           32520
# LEAF              13606
# MODEL S            7795
# BOLT EV            6780
# MODEL X            6239
# VOLT               4815
# ID.4               4716
# MUSTANG MACH-E     4363
# WRANGLER           4116
# Name: count, dtype: int64

# %% [markdown]
# The bar chart displays the top 10 most popular electric vehicle (EV) models based on registration counts. Tesla Model Y
# leads by a significant margin with over 44,000 registrations, followed by the Tesla Model 3 with around 32,500. This trend suggests Tesla's strong market presence and consumer preference for their models, likely due to Tesla's brand reputation, advanced technology, and extensive charging infrastructure. Nissan Leaf, a long-standing model in the EV market, ranks third, highlighting its continued popularity as an affordable EV option. Other notable models include Tesla’s Model S and Model X, Chevrolet Bolt EV, and Ford’s Mustang Mach-E. The data indicates that the market is dominated by a few popular models, particularly from Tesla, with some competition from established models like the Leaf and newer entries like the Mustang Mach-E.

# %% [markdown]
# # 2.3.2. Analyze Brand Popularity

# %%
brand_counts = df['Make'].value_counts()  # Count occurrences by 'Make' column (brand)

# Display the top 10 most popular brands
top_10_brands = brand_counts.head(10)
print("\nTop 10 EV Brands by Popularity:")
print(top_10_brands)

# Plot the popularity of the top 10 EV brands
plt.figure(figsize=(12, 6))
top_10_brands.plot(kind='bar', color='salmon')
plt.title("Top 10 Most Popular EV Brands")
plt.xlabel("EV Brand")
plt.ylabel("Number of Registrations")
plt.xticks(rotation=45)
plt.show()
# Out:
# Top 10 EV Brands by Popularity:
# Make
# TESLA         91379
# CHEVROLET     15419
# NISSAN        14721
# FORD          11138
# KIA            9576
# BMW            8607
# TOYOTA         8248
# HYUNDAI        6068
# RIVIAN         5883
# VOLKSWAGEN     5783
# Name: count, dtype: int64

# %% [markdown]
# The bar chart highlights the top 10 EV brands by registration count, with Tesla leading by a large margin at over 91,000 registrations. This dominance underscores Tesla's strong position in the EV market, driven by its technological innovations, brand loyalty, and extensive charging network. Following Tesla, Chevrolet and Nissan rank second and third, with 15,419 and 14,721 registrations, respectively, reflecting their established presence in the EV space through models like the Chevrolet Bolt and Nissan Leaf. Other brands, such as Ford, Kia, BMW, and Toyota, have moderate representation, indicating growing competition in the market but still trailing significantly behind Tesla. Newer entrants like Rivian also appear in the top 10, showing emerging interest in alternative EV brands.

# %% [markdown]
# # 2.3.3. Analyze Popularity by Electric Vehicle Type

# %%
type_counts = df['Electric Vehicle Type'].value_counts()  # Count occurrences by 'Electric Vehicle Type' column

# Display the count of each EV type
print("\nElectric Vehicle Type Distribution:")
print(type_counts)

# Plot the distribution of electric vehicle types
plt.figure(figsize=(8, 6))
type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['lightblue', 'lightgreen'])
plt.title("Distribution of Electric Vehicle Types")
plt.ylabel("")  # Hide y-label for a cleaner pie chart
plt.show()
# Out:
# Electric Vehicle Type Distribution:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            165554
# Plug-in Hybrid Electric Vehicle (PHEV)     44611
# Name: count, dtype: int64

# %% [markdown]
# The pie chart shows the distribution of electric vehicle types, with Battery Electric Vehicles (BEVs) making up
# the majority at 78.8% and Plug-in Hybrid Electric Vehicles (PHEVs) accounting for 21.2%. This indicates a strong preference for fully electric vehicles over hybrids among consumers, likely due to advancements in battery technology, longer range, and the expansion of charging infrastructure, which make BEVs more practical. The smaller share of PHEVs suggests that while they offer flexibility with both fuel and electric power, they are less popular as more consumers shift towards fully electric options.

# %% [markdown]
# # 2.3.4. Analyze Regional Popularity

# %%
county_model_counts = df.groupby(['County', 'Model']).size().unstack().fillna(0)  # Count occurrences by 'County' and 'Model'

# Display the top counties with the highest EV registrations
top_counties = df['County'].value_counts().head(5)
print("\nTop 5 Counties by EV Registrations:")
print(top_counties)

# Plot the top 5 counties by EV registrations (overall)
plt.figure(figsize=(10, 6))
top_counties.plot(kind='bar', color='lightcoral')
plt.title("Top 5 Counties by EV Registrations")
plt.xlabel("County")
plt.ylabel("Number of EV Registrations")
plt.xticks(rotation=45)
plt.show()
# Out:
# Top 5 Counties by EV Registrations:
# County
# King         107119
# Snohomish     25392
# Pierce        16677
# Clark         12537
# Thurston       7719
# Name: count, dtype: int64

# %% [markdown]
# The bar chart shows the top 5 counties in Washington by electric vehicle (EV) registrations. King County leads
# by a substantial margin, with over 107,000 registrations, far surpassing other counties. This high concentration is likely due to King County's urban population, which includes Seattle, as well as robust EV infrastructure and incentives that support EV adoption. Snohomish and Pierce counties follow, with around 25,000 and 16,000 registrations respectively, indicating moderate adoption in neighboring regions. Clark and Thurston counties have fewer registrations but still show a notable presence of EVs. This distribution suggests that urban and suburban areas with developed infrastructure and population density drive higher EV adoption rates in the state.

# %% [markdown]
# # 2.4. Investigate the relationship between every pair of numeric features. Are there any correlations? Explain the results.

# %% [markdown]
# Note that correlation values range from -1 to 1, where values close to 1 indicate a strong positive correlation
# and values close to -1 indicate a strong negative correlation. Specifically, values between 0 and 0.3 (or 0 and -0.3) suggest a weak correlation, indicating little to no linear relationship between the variables. Values between 0.3 and 0.7 (or -0.3 and -0.7) indicate a moderate correlation, which suggests a noticeable, though not perfect, linear relationship. Finally, values between 0.7 and 1.0 (or -0.7 and -1.0) signify a strong correlation, where one variable is highly predictive of the other.

# %%
import seaborn as sns

# Selecting only the numeric columns relevant to the analysis
numeric_features = ['Postal Code', 'Model Year', 'Electric Range', 'Base MSRP', 
                    'Legislative District', 'DOL Vehicle ID', '2020 Census Tract']

numeric_df = df[numeric_features] # Filter the dataframe to include only numeric features

correlation_matrix = numeric_df.corr()  # Calculate the correlation matrix

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Visualize the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, vmin=-1, vmax=1)
plt.title("Correlation Matrix of Numeric Features")
plt.show()
# Out:
# Correlation Matrix:
#                       Postal Code  Model Year  Electric Range  Base MSRP  \
# Postal Code              1.000000   -0.001291       -0.000800  -0.003409
# Model Year              -0.001291    1.000000       -0.513540  -0.230651
# Electric Range          -0.000800   -0.513540        1.000000   0.114155
# Base MSRP               -0.003409   -0.230651        0.114155   1.000000
# Legislative District     0.017785   -0.016191        0.018689   0.010035
# DOL Vehicle ID           0.005861    0.215703       -0.140695  -0.039501
# 2020 Census Tract        0.508744    0.004710       -0.000324  -0.000283
#
#                       Legislative District  DOL Vehicle ID  2020 Census Tract
# Postal Code                       0.017785        0.005861           0.508744
# Model Year                       -0.016191        0.215703           0.004710
# Electric Range                    0.018689       -0.140695          -0.000324
# ...

# %% [markdown]
# - Model Year and Electric Range: There is a moderate negative correlation (-0.51), suggesting that older EV
#
# - models generally have a shorter electric range compared to newer models. This reflects advancements in battery technology over time.
#
# - Model Year and DOL Vehicle ID: A moderate positive correlation (0.22) exists here, as expected, since newer vehicles likely have higher ID numbers, reflecting the sequential nature of registrations.
#
# - Model Year and Base MSRP: There is a weak negative correlation (-0.23), indicating that newer models might be slightly less expensive on average, which could be due to decreasing EV costs over time.
#
# - Postal Code and 2020 Census Tract: There is a moderate positive correlation (0.51), suggesting some alignment between these two geographic identifiers. This is logical since census tracts often correspond to specific postal codes.
#
# - Electric Range and Base MSRP: A weak positive correlation (0.11) is observed, implying that EVs with a higher range tend to have a slightly higher price, but the relationship is not strong.
#
# Most of the other relationships show very weak or near-zero correlations, indicating little to no linear relationship between those feature pairs. Overall, the matrix highlights a few moderate correlations related to model year, range, and geographic identifiers, which are in line with expectations for these types of features in an EV dataset.

# %% [markdown]
# # 3.1. Visualization

# %% [markdown]
# # 3.1.1. Histogram for Model Year

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Model Year'], bins=20, kde=True)
plt.title('Distribution of Model Year')
plt.xlabel('Model Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The histogram shows the distribution of electric vehicle (EV) model years in the dataset.
# There is a clear upward trend, with very few registrations for older models (before 2010) and a sharp increase in frequency starting around 2015. This trend indicates that most EVs in the dataset are relatively recent models, with a peak around 2022. The significant increase in newer models likely reflects growing adoption of EVs in recent years due to advancements in technology, increased availability, and possibly more incentives and support for EV purchases. The small drop-off toward 2025 may reflect incomplete data for that year, as newer models may still be in the process of registration.

# %% [markdown]
# # 3.1.2. Boxplot of Base MSRP by Electric Vehicle Type

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Electric Vehicle Type', y='Base MSRP')
plt.title('Base MSRP by Electric Vehicle Type')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Base MSRP ($)')
plt.show()

# %% [markdown]
# The boxplot compares the base MSRP of Plug-in Hybrid Electric Vehicles (PHEVs)
# and Battery Electric Vehicles (BEVs). Most vehicles in both categories have base MSRPs clustered toward the lower end of the scale, indicating that the majority of EVs are relatively affordable. However, there are a few notable outliers, particularly among BEVs, with prices reaching up to $800,000. This suggests that while the typical price for both vehicle types is within a similar range, some BEVs are significantly more expensive, likely due to high-end or luxury models. The plot highlights that BEVs have a wider range in pricing, reflecting a diversity of models and price points in the fully electric category.

# %% [markdown]
# # 3.1.3. Boxplot of Electric Range by Make

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df, x='Make', y='Electric Range')
plt.title('Electric Range by Make')
plt.xticks(rotation=90)
plt.xlabel('Make')
plt.ylabel('Electric Range (miles)')
plt.show()

# %% [markdown]
# The boxplot displays the distribution of electric range by vehicle make. Tesla stands out with a high median range and a wide range of values, reaching up to 300 miles, highlighting its focus on long-range electric vehicles. Other brands like Chevrolet, Ford, and BMW also show notable ranges, though their distributions are generally lower than Tesla’s, with fewer high-range outliers. Many brands, such as Fiat, Hyundai, and Volkswagen, have lower median ranges and tighter distributions, indicating that their models typically offer shorter ranges. This plot illustrates that Tesla dominates in terms of electric range, while other brands provide a mix of shorter-range options, possibly targeting different segments of the market. The presence of outliers in several brands suggests a few models with extended ranges, though these are not as common.

# %% [markdown]
# # 3.1.4. Scatter Plot for Electric Range vs. Model Year

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Model Year', y='Electric Range', color='purple', alpha=0.6)
plt.title("Electric Range Over Model Years")
plt.xlabel("Model Year")
plt.ylabel("Electric Range (miles)")
plt.show()

# %% [markdown]
# The scatter plot illustrates the relationship between electric vehicle (EV) model year and electric range. There is a clear upward trend in electric range over time, especially from around 2015 onward. Newer model years tend to have higher ranges, reflecting advancements in battery technology and increased focus on longer-range EVs. The clustering of data points below 100 miles for earlier model years suggests that older EVs generally had shorter ranges. In contrast, recent years show more models achieving ranges above 200 miles, with some reaching up to 300 miles or more. This trend highlights the progress made in EV technology to meet consumer demand for greater range.

# %% [markdown]
# # 3.1.5. Pairplot for Exploring Relationships Between Model Year, Electric Range, and Base MSRP

# %%
# Select relevant numerical columns for pairplot
numerical_columns = ['Model Year', 'Electric Range', 'Base MSRP']

# Pairplot to see the relationships among numerical features
sns.pairplot(df[numerical_columns])
plt.suptitle('Pairplot of Numerical Features', y=1.02)
plt.show()

# %% [markdown]
# This pairplot shows the relationships between Model Year, Electric Range, and Base MSRP for electric vehicles. Newer model years tend to have higher electric ranges, indicating advancements in battery technology and a focus on extended range in recent EV models. While the Base MSRP slightly increases with newer model years, this relationship is weak, possibly due to competitive pricing strategies. The scatter between Electric Range and Base MSRP suggests that vehicles with longer ranges generally cost more, as they likely require more advanced batteries. The individual feature distributions reveal that most EVs are concentrated in recent years (post-2015), have ranges below 100 miles, and are priced at lower MSRPs, with a few high-priced outliers likely representing luxury models.

# %% [markdown]
# # 3.1.6. Stacked Bar Plot for Electric Vehicle Distribution by City, County, and Type in Top Regions

# %%
# Count EVs by City and County (top 10 for simplicity)
city_counts = df['City'].value_counts().head(10)  # Top 10 cities by EV count
county_counts = df['County'].value_counts().head(10)  # Top 10 counties by EV count

# Set the figure size for all plots
plt.figure(figsize=(15, 12))

# Plot 1: Bar chart for EV distribution across top 10 cities
plt.subplot(3, 1, 1)
sns.barplot(x=city_counts.values, y=city_counts.index, hue=city_counts.index, palette='viridis', dodge=False, legend=False)
plt.title('Distribution of EVs Across Top 10 Cities')
plt.xlabel('Number of EVs')
plt.ylabel('City')

# Plot 2: Bar chart for EV distribution across top 10 counties
plt.subplot(3, 1, 2)
sns.barplot(x=county_counts.values, y=county_counts.index, hue=county_counts.index, palette='magma', dodge=False, legend=False)
plt.title('Distribution of EVs Across Top 10 Counties')
plt.xlabel('Number of EVs')
plt.ylabel('County')

# Plot 3: Stacked bar chart of EV Types by top 10 counties
# Create a pivot table for stacked bar chart by EV type across top 10 counties
ev_type_by_county = df[df['County'].isin(county_counts.index)].pivot_table(
    index='County', columns='Electric Vehicle Type', aggfunc='size', fill_value=0
)

# Plot stacked bar chart
plt.subplot(3, 1, 3)
ev_type_by_county.plot(kind='bar', stacked=True, colormap='coolwarm', ax=plt.gca())
plt.title('Distribution of EV Types Across Top 10 Counties')
plt.xlabel('County')
plt.ylabel('Number of EVs')
plt.legend(title='Electric Vehicle Type')

plt.tight_layout()
plt.show()

# %% [markdown]
# This figure shows the distribution of electric vehicles (EVs) across the top 10 cities and counties in Washington, along with the breakdown of EV types in these counties. Seattle and King County lead by a large margin, with Seattle having over 30,000 EVs and King County exceeding 100,000, indicating high EV adoption in urbanized areas. Other cities like Bellevue and counties like Snohomish and Pierce also have notable EV counts but lag significantly behind Seattle and King County. The stacked bar chart reveals a strong preference for Battery Electric Vehicles (BEVs) over Plug-in Hybrid Electric Vehicles (PHEVs) in these regions, particularly in King County. This distribution suggests that Washington's urban centers are the primary drivers of EV adoption, with a clear inclination towards fully electric models.

# %% [markdown]
# # 3.1.7. Heatmap for Electric Vehicle Type vs. County

# %%
top_counties = ev_type_by_county.sum(axis=1).nlargest(10).index  # Select top 10 counties by total EV count
ev_type_by_top_counties = ev_type_by_county.loc[top_counties]

plt.figure(figsize=(12, 6))
sns.heatmap(ev_type_by_top_counties, annot=True, fmt="d", cmap="YlGnBu", linewidths=0.5)
plt.title("Distribution of EV Types in Top Counties")
plt.xlabel("Electric Vehicle Type")
plt.ylabel("County")
plt.show()

# %% [markdown]
# This heatmap shows the distribution of electric vehicle (EV) types—Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs)—across the top counties in Washington by EV registrations. King County has the highest numbers, with 86,763 BEVs and 20,356 PHEVs, reflecting a strong preference for fully electric vehicles in this urbanized region. Snohomish and Pierce counties also have significant BEV counts (21,117 and 12,907, respectively) with smaller PHEV numbers, indicating a similar preference pattern. Other counties like Clark and Thurston have fewer EVs overall but maintain a higher proportion of BEVs. The heatmap reveals that BEVs are more popular than PHEVs across these top counties, particularly in urban centers where infrastructure and incentives likely support fully electric vehicles.

# %% [markdown]
# # 3.2. Comparative Visualization: Compare the distribution of EVs across different locations (cities, counties) using bar charts or stacked bar charts.

# %% [markdown]
# # 3.2.1. Distribution of EVs by County

# %%
county_counts = df['County'].value_counts().head(10)  # Top 10 counties for simplicity
plt.figure(figsize=(12, 6))
county_counts.plot(kind='bar', color='skyblue')
plt.title("Top 10 Counties by EV Registrations")
plt.xlabel("County")
plt.ylabel("Number of EV Registrations")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar chart displays the top 10 counties in Washington by the number of electric vehicle (EV) registrations.
# King County leads overwhelmingly with over 100,000 registrations, significantly outpacing other counties. Snohomish and Pierce counties follow, though with much lower counts, indicating that EV adoption is highly concentrated in King County, likely due to its larger urban population and infrastructure. Other counties like Clark, Thurston, and Kitsap show moderate levels of EV registrations, while the remaining counties have relatively low counts. This distribution highlights King County as a central hub for EV ownership in the state.

# %% [markdown]
# # 3.2.2. Distribution of EVs by City

# %%
city_counts = df['City'].value_counts().head(10)  # Top 10 cities for simplicity
plt.figure(figsize=(12, 6))
city_counts.plot(kind='bar', color='salmon')
plt.title("Top 10 Cities by EV Registrations")
plt.xlabel("City")
plt.ylabel("Number of EV Registrations")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar chart shows the top 10 cities in Washington by electric vehicle (EV) registrations. Seattle leads with a
# significant margin, having over 35,000 EV registrations, followed by Bellevue with much lower numbers. Other cities like Vancouver, Redmond, and Bothell have similar registration levels, indicating moderate EV adoption. The remaining cities—Renton, Kirkland, Sammamish, Olympia, and Tacoma—also show notable but lower counts. This distribution suggests that Seattle, as a major urban center, is the primary hub for EV ownership in Washington, likely due to its infrastructure and supportive policies for EV adoption.

# %% [markdown]
# # 3.2.3. Stacked Bar Chart for EV Type Distribution by County (Top 5 Counties)

# %%
top_counties = df['County'].value_counts().index[:5]  # Top 5 counties for a cleaner stacked bar chart
county_ev_type_counts = df[df['County'].isin(top_counties)].groupby(['County', 'Electric Vehicle Type']).size().unstack(fill_value=0)

# Plotting the stacked bar chart
county_ev_type_counts.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title("Distribution of EV Types in Top 5 Counties")
plt.xlabel("County")
plt.ylabel("Number of EV Registrations")
plt.xticks(rotation=45)
plt.legend(title="EV Type")
plt.show()

# %% [markdown]
# The bar chart displays the distribution of EV types (Battery Electric Vehicles (BEVs) and Plug-in Hybrid
# Electric Vehicles (PHEVs)) in the top 5 counties by EV registrations. King County has the highest number of registrations, with BEVs making up the majority and a smaller portion for PHEVs, reflecting a strong preference for fully electric vehicles. Snohomish and Pierce counties also show a similar trend, with BEVs dominating but with a noticeable presence of PHEVs. Clark and Thurston counties have fewer overall registrations, but the ratio of BEVs to PHEVs remains consistent with other counties. This distribution suggests a preference for fully electric vehicles across these regions, especially in urban and high-population areas.

# %% [markdown]
# # 4. Temporal Analysis

# %% [markdown]
# # 4.1. EV Adoption Over Time (using Model Year)

# %%
# Count the number of EVs by Model Year
ev_adoption_by_year = df['Model Year'].value_counts().sort_index()  # Sorting by year for chronological order

# Plot EV adoption over time
plt.figure(figsize=(12, 6))
ev_adoption_by_year.plot(kind='line', marker='o', color='blue')
plt.title("EV Adoption Over Time")
plt.xlabel("Model Year")
plt.ylabel("Number of EV Registrations")
plt.grid(True)
plt.show()

# %% [markdown]
# The plot shows how the number of electric vehicle (EV) registrations has changed over time by model year.
# Starting around 2010, EV registrations gradually increased, with a big jump after 2018, reaching a peak in recent years. This growth likely reflects more people choosing EVs, better technology, and support for EVs through incentives. The drop at the end may be because data for the latest models or 2025 isn’t fully recorded yet.

# %% [markdown]
# # 4.2. Model Popularity Over Time

# %%
# Count top 5 popular models overall
top_models = df['Model'].value_counts().head(5).index

# Filter dataset to include only the top 5 models
df_top_models = df[df['Model'].isin(top_models)]

# Group by Model Year and Model to see the popularity over time
model_popularity_over_time = df_top_models.groupby(['Model Year', 'Model']).size().unstack(fill_value=0)

# Plot model popularity over time
plt.figure(figsize=(12, 8))
model_popularity_over_time.plot(kind='line', marker='o')
plt.title("Top 5 EV Models Popularity Over Time")
plt.xlabel("Model Year")
plt.ylabel("Number of Registrations")
plt.legend(title="Model")
plt.grid(True)
plt.show()

# %% [markdown]
# The plot shows the popularity of the top 5 electric vehicle (EV) models over time by model year. Tesla's Model Y
# leads with a sharp increase around 2023, followed by Model 3, which also saw a peak in recent years. Nissan Leaf and Chevrolet Bolt EV have more stable but lower numbers, indicating steady but less dominant popularity. The Tesla Model S shows moderate popularity, increasing around 2018 but remaining below Model Y and Model 3 levels. This trend highlights Tesla's strong hold on the EV market in recent years, especially with Model Y and Model 3. The decline at the end likely reflects incomplete data for the latest model years.
